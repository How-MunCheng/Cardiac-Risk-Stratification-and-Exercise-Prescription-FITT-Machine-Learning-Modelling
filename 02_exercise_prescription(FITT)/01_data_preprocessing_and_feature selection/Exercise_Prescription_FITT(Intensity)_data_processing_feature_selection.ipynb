# %%
# LOAD DATASET WITH PREDICTED RISK LEVEL

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

file_path = (
    "/content/drive/MyDrive/"
    "dataset_with_predicted_risk.csv"
)

df = pd.read_csv(file_path)

print("Dataset loaded successfully")

print("\nShape:")
print(df.shape)

print("\nFirst 5 rows:")
print(df.head())

print("\nColumns:")
print(df.columns.tolist())
# Out:
# Mounted at /content/drive
# Dataset loaded successfully
#
# Shape:
# (330, 50)
#
# First 5 rows:
#      Year  ID         DOB Gender   Age Marital Status Lives With  \
# 0  2022.0   1  1969-05-28      M  53.0        married     family
# 1  2022.0   2  1953-03-28      F  69.0        married     family
# 2  2022.0   3  1953-03-16      F  69.0        married     family
# 3  2022.0   4  1952-03-24      M  70.0        married     family
# 4  2022.0   5  1948-03-25      M  74.0        married     family
#
#   Living Environment   Occupation     Smoking  ... Diagnosis Target HR (%)  \
# 0                FOS  not working  ex smoker   ...   unknown          50.0
# 1             landed      retired          no  ...   unknown          60.0
# 2                FOS      unknown          no  ...   unknown          50.0
# 3            unknown      retired          no  ...       PCI          60.0
# 4                FOS      retired  ex smoker   ...       PCI          50.0
#
#   Target HR (bpm) Recumbent bike : RES Recumbent bike : Duration  \
# 0           109.0                    3                      10.0
# 1           106.0                    2                      10.0
# 2            99.0                    3                      10.0
# 3           115.0                    3                      10.0
# 4            89.0                    2                      10.0
#
#   Recumbent bike : MHR  Recumbent bike : RPE  Cooling Down  \
# 0                109.0                  11.0        Visual
# 1                106.0                  13.0       unknown
# 2                 99.0                  12.0        Visual
# 3                118.0                  13.0        Visual
# 4                 91.0                  13.0        Visual
#
#    Predicted Risk Level  Predicted Risk Level Encoded
# 0                  high                             2
# 1                   low                             0
# 2                  high                             2
# 3              moderate                             1
# 4                  high                             2
#
# [5 rows x 50 columns]
#
# Columns:
# ['Year', 'ID', 'DOB', 'Gender', 'Age', 'Marital Status', 'Lives With', 'Living Environment', 'Occupation', 'Smoking', 'Alcoholic', 'Family History', 'Exercise Habit - Frequency', 'Exercise Habit - Mode', 'Exercise Habit - Duration', 'ROM', 'Muscle Power - UL - Right', 'Muscle Power - UL - Left', 'Muscle Power - LL - Right', 'Muscle Power - LL - Left', 'Balance in Sitting and Standing', 'Functional Activity', 'Walking', 'Gait', 'Posture', 'Risk Level', 'Risk Factor - HPT', 'Risk Factor - DM', 'Risk Factor - HPL', 'Risk Factor - Family hx', 'Risk Factor - Exercise', 'Risk Factor - Stress', 'Risk Factor - Smoking', 'Risk Factor - BMI', 'Risk Factor - ECHO - EF', 'Test Today - Termination Cause', 'Test Today - peak HR', 'Test Today - METS', 'ECG Resting', 'RISK  - Risk Type', 'Diagnosis', 'Target HR (%)', 'Target HR (bpm)', 'Recumbent bike : RES', 'Recumbent bike : Duration', 'Recumbent bike : MHR', 'Recumbent bike : RPE', 'Cooling Down', 'Predicted Risk Level', 'Predicted Risk Level Encoded']

# %%
# SAVE TARGET BEFORE CLEANING
target_col = 'Target HR (bpm)'

# Show columns before dropping irrelevant ones
print("Columns before dropping irrelevant:")
print(df.columns.tolist())

# Drop Identifier and Irrelevant Columns
# Remove unwanted features (not gonna used as told by sv, corresponding to shiling's paper) in raw data: 'Recumbent bike : RES','Recumbent bike : Duration','Recumbent bike : MHR','Recumbent bike : RPE','Target HR (bpm)','Target HR (%)']
cols_to_drop = [
    'Risk Level',   # original label → leakage
    'Predicted Risk Level',
    'ID', 'DOB',
    'Recumbent bike : RES',
    'Recumbent bike : Duration',
    'Recumbent bike : MHR',
    'Recumbent bike : RPE',
    'Target HR (%)'
]

df = df.drop(columns=[c for c in cols_to_drop if c in df.columns])

print("Features shape after dropped features:", df.shape)
print("Remaining columns after dropping identifier columns:", df.columns.tolist())
# Out:
# Columns before dropping irrelevant:
# ['Year', 'ID', 'DOB', 'Gender', 'Age', 'Marital Status', 'Lives With', 'Living Environment', 'Occupation', 'Smoking', 'Alcoholic', 'Family History', 'Exercise Habit - Frequency', 'Exercise Habit - Mode', 'Exercise Habit - Duration', 'ROM', 'Muscle Power - UL - Right', 'Muscle Power - UL - Left', 'Muscle Power - LL - Right', 'Muscle Power - LL - Left', 'Balance in Sitting and Standing', 'Functional Activity', 'Walking', 'Gait', 'Posture', 'Risk Level', 'Risk Factor - HPT', 'Risk Factor - DM', 'Risk Factor - HPL', 'Risk Factor - Family hx', 'Risk Factor - Exercise', 'Risk Factor - Stress', 'Risk Factor - Smoking', 'Risk Factor - BMI', 'Risk Factor - ECHO - EF', 'Test Today - Termination Cause', 'Test Today - peak HR', 'Test Today - METS', 'ECG Resting', 'RISK  - Risk Type', 'Diagnosis', 'Target HR (%)', 'Target HR (bpm)', 'Recumbent bike : RES', 'Recumbent bike : Duration', 'Recumbent bike : MHR', 'Recumbent bike : RPE', 'Cooling Down', 'Predicted Risk Level', 'Predicted Risk Level Encoded']
# Features shape after dropped features: (330, 41)
# Remaining columns after dropping identifier columns: ['Year', 'Gender', 'Age', 'Marital Status', 'Lives With', 'Living Environment', 'Occupation', 'Smoking', 'Alcoholic', 'Family History', 'Exercise Habit - Frequency', 'Exercise Habit - Mode', 'Exercise Habit - Duration', 'ROM', 'Muscle Power - UL - Right', 'Muscle Power - UL - Left', 'Muscle Power - LL - Right', 'Muscle Power - LL - Left', 'Balance in Sitting and Standing', 'Functional Activity', 'Walking', 'Gait', 'Posture', 'Risk Factor - HPT', 'Risk Factor - DM', 'Risk Factor - HPL', 'Risk Factor - Family hx', 'Risk Factor - Exercise', 'Risk Factor - Stress', 'Risk Factor - Smoking', 'Risk Factor - BMI', 'Risk Factor - ECHO - EF', 'Test Today - Termination Cause', 'Test Today - peak HR', 'Test Today - METS', 'ECG Resting', 'RISK  - Risk Type', 'Diagnosis', 'Target HR (bpm)', 'Cooling Down', 'Predicted Risk Level Encoded']

# %%
# PRINT UNIQUE VALUES + COUNTS
for col in df.columns:
    print(f"\n=== {col} ===")
    print(f"Unique values ({df[col].nunique()}):")
    print(df[col].dropna().unique())

    # Count missing
    missing_count = df[col].isna().sum()
    print(f"Missing: {missing_count}")

    if df[col].dtype == 'object':
        # Categorical
        print("Type: Categorical")

        value_counts = df[col].value_counts(dropna=False)

        print(f"Unique categories ({df[col].nunique(dropna=True)}):")
        print(value_counts)

    else:
        # Numerical
        print("Type: Numerical")

        print(f"Min: {df[col].min()}, Max: {df[col].max()}")
        print(f"Mean: {df[col].mean()}")
        print(f"Unique count: {df[col].nunique()}")

        # Optional: still show distribution (very useful)
        print("\nValue counts (top 10):")
        print(df[col].value_counts().head(10))
# Out:
# === Year ===
# Unique values (5):
# [2022. 2021. 2020. 2019. 2018.]
# Missing: 0
# Type: Numerical
# Min: 2018.0, Max: 2022.0
# Mean: 2020.569696969697
# Unique count: 5
#
# Value counts (top 10):
# Year
# 2021.0    111
# 2022.0     85
# 2019.0     83
# 2020.0     46
# 2018.0      5
# Name: count, dtype: int64
#
# === Gender ===
# Unique values (2):
# ['M' 'F']
# Missing: 0
# Type: Categorical
# Unique categories (2):
# Gender
# M    265
# F     65
# Name: count, dtype: int64
#
# === Age ===
# Unique values (57):
# [53. 69. 70. 74. 51. 66. 64. 63. 59. 67. 75. 47. 36. 56. 60. 71. 65. 55.
#  68. 54. 52. 80. 45. 42. 62. 41. 48. 72. 40. 50. 43. 33. 46. 58. 78. 38.
#  76. 37. 73. 57. 34. 86. 84. 49. 44. 35. 61. 29. 39. 77. 27. 28. 81. 87.
#  26. 85. 79.]
# Missing: 0
# Type: Numerical
# Min: 26.0, Max: 87.0
# Mean: 59.67272727272727
# Unique count: 57
#
# Value counts (top 10):
# Age
# 64.0    18
# 59.0    16
# 66.0    15
# 62.0    14
# 60.0    13
# 70.0    12
# 67.0    11
# 69.0    11
# 63.0    10
# 68.0    10
# Name: count, dtype: int64
#
# === Marital Status ===
# Unique values (5):
# ['married' 'single' 'unknown' 'divorced' 'widow']
# Missing: 0
# Type: Categorical
# Unique categories (5):
# Marital Status
# married     210
# unknown      98
# single       19
# divorced      2
# widow         1
# Name: count, dtype: int64
#
# === Lives With ===
# Unique values (4):
# ['family' 'unknown' 'friends' 'alone ']
# Missing: 0
# Type: Categorical
# Unique categories (4):
# Lives With
# family     220
# unknown    100
# alone        8
# friends      2
# Name: count, dtype: int64
#
# === Living Environment ===
# Unique values (3):
# ['FOS' 'landed' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Living Environment
# unknown    181
# FOS        148
# landed       1
# Name: count, dtype: int64
#
# === Occupation ===
# Unique values (5):
# ['not working' 'retired' 'unknown' 'employed' 'self employed']
# Missing: 0
# Type: Categorical
# Unique categories (5):
# Occupation
# unknown          119
# employed          97
# retired           66
# not working       34
# self employed     14
# Name: count, dtype: int64
#
# === Smoking ===
# Unique values (4):
# ['ex smoker ' 'no' 'yes' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (4):
# Smoking
# unknown       115
# ex smoker     103
# no             86
# yes            26
# Name: count, dtype: int64
#
# === Alcoholic ===
# Unique values (4):
# ['occasionally' 'unknown' 'no' 'yes']
# Missing: 0
# Type: Categorical
# Unique categories (4):
# Alcoholic
# unknown         226
# no               73
# occasionally     26
# yes               5
# Name: count, dtype: int64
#
# === Family History ===
# Unique values (3):
# ['yes' 'no' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Family History
# yes        143
# unknown    126
# no          61
# Name: count, dtype: int64
#
# === Exercise Habit - Frequency ===
# Unique values (17):
# ['7 times per week' 'unknown' '2 times per week' '0 times per week'
#  '4 times per week' '2-3 times per week' '6 times per week'
#  '5 times per week' '1 times per week' '1-2 times per week'
#  '3 times per week' '4-5 times per week' '3-4 times per week'
#  '5-6 times per week' '3-5 times per week' '14 times per week'
#  '6-7 times per week']
# Missing: 0
# Type: Categorical
# Unique categories (17):
# Exercise Habit - Frequency
# unknown               117
# 7 times per week       69
# 3-4 times per week     20
# 0 times per week       18
# 2 times per week       15
# 3 times per week       15
# 1 times per week       14
# 5 times per week       14
# 2-3 times per week     12
# 1-2 times per week     10
# 4 times per week        8
# 5-6 times per week      5
# 4-5 times per week      4
# 6 times per week        3
# 3-5 times per week      3
# 14 times per week       2
# 6-7 times per week      1
# Name: count, dtype: int64
#
# === Exercise Habit - Mode ===
# Unique values (10):
# ['walking' 'others' 'unknown' 'cycling' 'no' 'jogging' 'walking+cycling'
#  'jogging+cycling' 'walking+jogging' 'walking+jogging+cycling']
# Missing: 0
# Type: Categorical
# Unique categories (10):
# Exercise Habit - Mode
# walking                    154
# unknown                    102
# others                      32
# cycling                     15
# no                           9
# jogging                      9
# walking+cycling              4
# jogging+cycling              2
# walking+jogging              2
# walking+jogging+cycling      1
# Name: count, dtype: int64
#
# === Exercise Habit - Duration ===
# Unique values (27):
# ['unknown' '30 mins per session' '10 mins per session '
#  '60-120 mins per session ' '45 mins per session' '60 mins per session'
#  '25 mins per session' '120 mins per session' '20-30 mins per session'
#  '30-60 mins per session' '50 mins per session' '40 mins per session'
#  '20 mins per session ' '30-45 mins per session' '15-20 mins per session'
#  '90 mins per session' '15 mins per session' '30-40 mins per session'
#  '10-15 mins per session' '40-60 mins per session'
#  '15-30 mins per session' '5-10 mins per session' '45-60 mins per session'
#  '55 mins per session' '20-30 mins per session ' '5 mins per session'
#  '480 mins per session']
# Missing: 0
# Type: Categorical
# Unique categories (27):
# Exercise Habit - Duration
# unknown                     152
# 30 mins per session          58
# 60 mins per session          22
# 20 mins per session          15
# 10 mins per session          11
# 10-15 mins per session        7
# 20-30 mins per session        7
# 45 mins per session           6
# 15 mins per session           5
# 40 mins per session           5
# 30-40 mins per session        5
# 30-60 mins per session        4
# 40-60 mins per session        4
# 25 mins per session           3
# 120 mins per session          3
# 45-60 mins per session        3
# 50 mins per session           3
# 15-20 mins per session        3
# 30-45 mins per session        3
# 5-10 mins per session         3
# 15-30 mins per session        2
# 60-120 mins per session       1
# 90 mins per session           1
# 55 mins per session           1
# 20-30 mins per session        1
# 5 mins per session            1
# 480 mins per session          1
# Name: count, dtype: int64
#
# === ROM ===
# Unique values (3):
# ['abnormal' 'normal' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# ROM
# normal      295
# abnormal     23
# unknown      12
# Name: count, dtype: int64
#
# === Muscle Power - UL - Right ===
# Unique values (3):
# [3. 5. 4.]
# Missing: 9
# Type: Numerical
# Min: 3.0, Max: 5.0
# Mean: 4.947040498442368
# Unique count: 3
#
# Value counts (top 10):
# Muscle Power - UL - Right
# 5.0    309
# 4.0      7
# 3.0      5
# Name: count, dtype: int64
#
# === Muscle Power - UL - Left ===
# Unique values (4):
# [2. 5. 4. 3.]
# Missing: 9
# Type: Numerical
# Min: 2.0, Max: 5.0
# Mean: 4.947040498442368
# Unique count: 4
#
# Value counts (top 10):
# Muscle Power - UL - Left
# 5.0    310
# 4.0      7
# 2.0      2
# 3.0      2
# Name: count, dtype: int64
#
# === Muscle Power - LL - Right ===
# Unique values (4):
# [5. 4. 3. 2.]
# Missing: 10
# Type: Numerical
# Min: 2.0, Max: 5.0
# Mean: 4.940625
# Unique count: 4
#
# Value counts (top 10):
# Muscle Power - LL - Right
# 5.0    305
# 4.0     12
# 3.0      2
# 2.0      1
# Name: count, dtype: int64
#
# === Muscle Power - LL - Left ===
# Unique values (4):
# [5. 4. 3. 2.]
# Missing: 10
# Type: Numerical
# Min: 2.0, Max: 5.0
# Mean: 4.9375
# Unique count: 4
#
# Value counts (top 10):
# Muscle Power - LL - Left
# 5.0    306
# 4.0     10
# 3.0      2
# 2.0      2
# Name: count, dtype: int64
#
# === Balance in Sitting and Standing ===
# Unique values (3):
# ['yes' 'no' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Balance in Sitting and Standing
# yes        311
# unknown     14
# no           5
# Name: count, dtype: int64
#
# === Functional Activity ===
# Unique values (3):
# ['independent ' 'unknown' 'assisted']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Functional Activity
# independent     312
# unknown          17
# assisted          1
# Name: count, dtype: int64
#
# === Walking ===
# Unique values (3):
# ['independent' 'dependent' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Walking
# independent    306
# unknown         17
# dependent        7
# Name: count, dtype: int64
#
# === Gait ===
# Unique values (3):
# ['normal' 'abnormal' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Gait
# normal      302
# abnormal     14
# unknown      14
# Name: count, dtype: int64
#
# === Posture ===
# Unique values (3):
# ['normal' 'unknown' 'abnormal']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Posture
# normal      289
# unknown      26
# abnormal     15
# Name: count, dtype: int64
#
# === Risk Factor - HPT ===
# Unique values (3):
# ['yes' 'no' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Risk Factor - HPT
# unknown    133
# no         121
# yes         76
# Name: count, dtype: int64
#
# === Risk Factor - DM ===
# Unique values (3):
# ['yes' 'unknown' 'no']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Risk Factor - DM
# yes        159
# no          89
# unknown     82
# Name: count, dtype: int64
#
# === Risk Factor - HPL ===
# Unique values (3):
# ['no' 'yes' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Risk Factor - HPL
# unknown    174
# no         104
# yes         52
# Name: count, dtype: int64
#
# === Risk Factor - Family hx ===
# Unique values (3):
# ['yes' 'no' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Risk Factor - Family hx
# yes        145
# unknown     97
# no          88
# Name: count, dtype: int64
#
# === Risk Factor - Exercise ===
# Unique values (4):
# ['moderate' 'active' 'inactive' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (4):
# Risk Factor - Exercise
# unknown     97
# moderate    83
# inactive    81
# active      69
# Name: count, dtype: int64
#
# === Risk Factor - Stress ===
# Unique values (3):
# ['yes' 'unknown' 'no']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Risk Factor - Stress
# no         142
# unknown    112
# yes         76
# Name: count, dtype: int64
#
# === Risk Factor - Smoking ===
# Unique values (4):
# ['ex smoker ' 'no' 'yes' 'unknown']
# Missing: 0
# Type: Categorical
# Unique categories (4):
# Risk Factor - Smoking
# no            148
# unknown        82
# ex smoker      69
# yes            31
# Name: count, dtype: int64
#
# === Risk Factor - BMI ===
# Unique values (5):
# ['unknown' 'healthy' 'overweight' 'obese' 'underweight']
# Missing: 0
# Type: Categorical
# Unique categories (5):
# Risk Factor - BMI
# unknown        102
# healthy         99
# overweight      83
# obese           40
# underweight      6
# Name: count, dtype: int64
#
# === Risk Factor - ECHO - EF ===
# Unique values (4):
# ['reduced' 'normal' 'unknown' 'borderline']
# Missing: 0
# Type: Categorical
# Unique categories (4):
# Risk Factor - ECHO - EF
# unknown       151
# normal        132
# borderline     36
# reduced        11
# Name: count, dtype: int64
#
# === Test Today - Termination Cause ===
# Unique values (7):
# ['Fatigue' 'Complete Test' 'Medical Condition' 'Physical Discomfort'
#  'Fatigue+Physical Discomfort' 'unknown' 'Fatigue+Medical Condition']
# Missing: 0
# Type: Categorical
# Unique categories (7):
# Test Today - Termination Cause
# Fatigue                        137
# Complete Test                   83
# Physical Discomfort             67
# unknown                         20
# Fatigue+Physical Discomfort     14
# Medical Condition                8
# Fatigue+Medical Condition        1
# Name: count, dtype: int64
#
# === Test Today - peak HR ===
# Unique values (6):
# ['moderate intensity' 'high intensity' 'maximum intensity'
#  'above maximum intensity' 'unknown' 'low intensity']
# Missing: 0
# Type: Categorical
# Unique categories (6):
# Test Today - peak HR
# high intensity             175
# moderate intensity         110
# above maximum intensity     15
# unknown                     11
# low intensity               10
# maximum intensity            9
# Name: count, dtype: int64
#
# === Test Today - METS ===
# Unique values (5):
# ['high intensity' 'moderate intensity (high)' 'unknown'
#  'moderate intensity (low)' 'low intensity']
# Missing: 0
# Type: Categorical
# Unique categories (5):
# Test Today - METS
# high intensity               258
# moderate intensity (high)     46
# moderate intensity (low)      16
# unknown                        8
# low intensity                  2
# Name: count, dtype: int64
#
# === ECG Resting ===
# Unique values (13):
# ['sinus rhythm' 'unknown' 'T wave inversion' 'sinus rhythm+Ectopics'
#  'sinus rhythm+st depression' 'sinus rhythm+T wave inversion' 'normal'
#  'sinus rhythm+Q wave' 'st depression' 'T wave inversion+Q Wave'
#  'sinus rhythm+Q wave+Ectopics' 'Q wave' 'st depression+Q wave']
# Missing: 0
# Type: Categorical
# Unique categories (13):
# ECG Resting
# unknown                          140
# sinus rhythm                     102
# sinus rhythm+T wave inversion     24
# T wave inversion                  21
# normal                            19
# sinus rhythm+Q wave                8
# sinus rhythm+st depression         4
# st depression                      4
# T wave inversion+Q Wave            3
# Q wave                             2
# sinus rhythm+Ectopics              1
# sinus rhythm+Q wave+Ectopics       1
# st depression+Q wave               1
# Name: count, dtype: int64
#
# === RISK  - Risk Type ===
# Unique values (6):
# ['moderate' 'low' 'unknown' 'moderate to high' 'low to moderate' 'high']
# Missing: 0
# Type: Categorical
# Unique categories (6):
# RISK  - Risk Type
# moderate            192
# low                 124
# unknown               9
# moderate to high      2
# low to moderate       2
# high                  1
# Name: count, dtype: int64
#
# === Diagnosis ===
# Unique values (9):
# ['unknown' 'PCI' 'conservative' 'CABG' 'surgical' 'PCI+CABG'
#  'PCI+conservative' 'surgical+conservative' 'CABG+conservative']
# Missing: 0
# Type: Categorical
# Unique categories (9):
# Diagnosis
# PCI                      150
# unknown                   87
# CABG                      41
# conservative              28
# surgical                  14
# PCI+CABG                   5
# PCI+conservative           3
# surgical+conservative      1
# CABG+conservative          1
# Name: count, dtype: int64
#
# === Target HR (bpm) ===
# Unique values (73):
# [109.  106.   99.  115.   89.  100.   80.  102.   94.   90.   85.  120.
#  111.  118.  108.  105.   73.  128.  114.   75.   98.   91.   74.  107.
#  112.5  95.   86.  143.  122.   93.  110.  116.   96.   97.  104.   84.
#  123.   83.  124.  121.8 101.   88.  121.  103.   58.  113.  140.   92.
#   81.  112.  117.   87.  122.5  66.  139.   82.   79.5  77.  127.  138.5
#  106.5  70.   76.  131.  150.  126.  119.  135.   96.5  98.5 115.5 156.
#  116.5]
# Missing: 19
# Type: Numerical
# Min: 58.0, Max: 156.0
# Mean: 103.84983922829582
# Unique count: 73
#
# Value counts (top 10):
# Target HR (bpm)
# 100.0    14
# 90.0     11
# 94.0     10
# 120.0    10
# 111.0    10
# 105.0    10
# 91.0      9
# 98.0      9
# 108.0     9
# 95.0      9
# Name: count, dtype: int64
#
# === Cooling Down ===
# Unique values (3):
# ['Visual' 'unknown' 'Extended']
# Missing: 0
# Type: Categorical
# Unique categories (3):
# Cooling Down
# Visual      157
# unknown     113
# Extended     60
# Name: count, dtype: int64
#
# === Predicted Risk Level Encoded ===
# Unique values (3):
# [2 0 1]
# Missing: 0
# Type: Numerical
# Min: 0, Max: 2
# Mean: 1.2969696969696969
# Unique count: 3
#
# Value counts (top 10):
# Predicted Risk Level Encoded
# 2    193
# 0     95
# 1     42
# Name: count, dtype: int64

# %%
# Drop columns of features with over 60% missing data

import pandas as pd, numpy as np, unicodedata
from sklearn.impute import KNNImputer

# Normalize string-like missing values
def normalize_cell_keep_valid(x):
    if pd.isna(x):
        return np.nan
    if isinstance(x, str):
        s = unicodedata.normalize('NFKC', x)
        s = s.replace('\xa0','').replace('\u200b','').replace('\ufeff','').strip()
        if s.lower() in {'', 'na','n/a','none','null','nan','unknown','to confirm','-','--'}:
            return np.nan
        return s
    return x

obj_cols = df.select_dtypes(include='object').columns.tolist()
for c in obj_cols:
    df[c] = df[c].apply(normalize_cell_keep_valid)


# 1. Diagnostics: dtypes + NaN
print("1) dtypes and current NaN counts (pandas view):")
print(df.dtypes)
print(df.isna().sum().sort_values(ascending=False).head(50))
print("-"*60)

# 2. String-like missing tokens
missing_tokens = {'', 'na', 'n/a', 'none', 'null', 'nan', 'unknown', 'to confirm', '-', '--'}

def count_string_like(col):
    if col.dtype != 'O':
        return 0, []
    s = col.astype(str).str.strip().str.lower()
    mask = s.isin(missing_tokens)
    return int(mask.sum()), pd.unique(s[mask])[:20]

print("2) Columns containing string-like missing tokens:")
for c in df.columns:
    cnt, sample_vals = count_string_like(df[c])
    if cnt > 0:
        print(f" - {c}: {cnt} string-like missing (examples: {list(sample_vals)})")
print("-"*60)

# --------------------------------------------------
# 3. Clean object columns
# --------------------------------------------------
obj_cols = df.select_dtypes(include='object').columns.tolist()
print("3) Cleaning object columns:", obj_cols)
for c in obj_cols:
    df[c] = df[c].apply(normalize_cell_keep_valid)

# --------------------------------------------------
# 4. Diagnostics after cleaning
# --------------------------------------------------
print("-" * 60)
print("4) After cleaning: dtype and NaN counts:")
missing_counts = df.isna().sum().sort_values(ascending=False)
print(missing_counts[missing_counts > 0])
print("Total missing:", missing_counts.sum())
print("-" * 60)

# --------------------------------------------------
# 5. Drop columns with >60% missing
# --------------------------------------------------
threshold = 0.6
dropped_cols = df.columns[df.isna().mean() > threshold].tolist()
df = df.drop(columns=dropped_cols)

print("Dropped columns (missing > 60%):", dropped_cols)
print("Remaining columns:", df.shape)
print("Remaining columns:", df.columns.tolist())
# Out:
# 1) dtypes and current NaN counts (pandas view):
# Year                               float64
# Gender                              object
# Age                                float64
# Marital Status                      object
# Lives With                          object
# Living Environment                  object
# Occupation                          object
# Smoking                             object
# Alcoholic                           object
# Family History                      object
# Exercise Habit - Frequency          object
# Exercise Habit - Mode               object
# Exercise Habit - Duration           object
# ROM                                 object
# Muscle Power - UL - Right          float64
# Muscle Power - UL - Left           float64
# Muscle Power - LL - Right          float64
# Muscle Power - LL - Left           float64
# Balance in Sitting and Standing     object
# Functional Activity                 object
# Walking                             object
# Gait                                object
# Posture                             object
# Risk Factor - HPT                   object
# Risk Factor - DM                    object
# Risk Factor - HPL                   object
# Risk Factor - Family hx             object
# Risk Factor - Exercise              object
# Risk Factor - Stress                object
# Risk Factor - Smoking               object
# Risk Factor - BMI                   object
# Risk Factor - ECHO - EF             object
# Test Today - Termination Cause      object
# Test Today - peak HR                object
# Test Today - METS                   object
# ECG Resting                         object
# RISK  - Risk Type                   object
# Diagnosis                           object
# Target HR (bpm)                    float64
# Cooling Down                        object
# Predicted Risk Level Encoded         int64
# dtype: object
# Alcoholic                          226
# Living Environment                 181
# Risk Factor - HPL                  174
# Exercise Habit - Duration          152
# Risk Factor - ECHO - EF            151
# ECG Resting                        140
# Risk Factor - HPT                  133
# Family History                     126
# Occupation                         119
# Exercise Habit - Frequency         117
# Smoking                            115
# Cooling Down                       113
# Risk Factor - Stress               112
# Risk Factor - BMI                  102
# Exercise Habit - Mode              102
# Lives With                         100
# Marital Status                      98
# Risk Factor - Family hx             97
# Risk Factor - Exercise              97
# Diagnosis                           87
# Risk Factor - Smoking               82
# Risk Factor - DM                    82
# Posture                             26
# Test Today - Termination Cause      20
# Target HR (bpm)                     19
# Functional Activity                 17
# Walking                             17
# Gait                                14
# Balance in Sitting and Standing     14
# ROM                                 12
# Test Today - peak HR                11
# Muscle Power - LL - Left            10
# Muscle Power - LL - Right           10
# Muscle Power - UL - Right            9
# RISK  - Risk Type                    9
# Muscle Power - UL - Left             9
# Test Today - METS                    8
# Age                                  0
# Gender                               0
# Year                                 0
# Predicted Risk Level Encoded         0
# dtype: int64
# ------------------------------------------------------------
# 2) Columns containing string-like missing tokens:
#  - Marital Status: 98 string-like missing (examples: ['nan'])
#  - Lives With: 100 string-like missing (examples: ['nan'])
#  - Living Environment: 181 string-like missing (examples: ['nan'])
#  - Occupation: 119 string-like missing (examples: ['nan'])
#  - Smoking: 115 string-like missing (examples: ['nan'])
#  - Alcoholic: 226 string-like missing (examples: ['nan'])
#  - Family History: 126 string-like missing (examples: ['nan'])
#  - Exercise Habit - Frequency: 117 string-like missing (examples: ['nan'])
#  - Exercise Habit - Mode: 102 string-like missing (examples: ['nan'])
#  - Exercise Habit - Duration: 152 string-like missing (examples: ['nan'])
#  - ROM: 12 string-like missing (examples: ['nan'])
#  - Balance in Sitting and Standing: 14 string-like missing (examples: ['nan'])
#  - Functional Activity: 17 string-like missing (examples: ['nan'])
#  - Walking: 17 string-like missing (examples: ['nan'])
#  - Gait: 14 string-like missing (examples: ['nan'])
#  - Posture: 26 string-like missing (examples: ['nan'])
#  - Risk Factor - HPT: 133 string-like missing (examples: ['nan'])
#  - Risk Factor - DM: 82 string-like missing (examples: ['nan'])
#  - Risk Factor - HPL: 174 string-like missing (examples: ['nan'])
#  - Risk Factor - Family hx: 97 string-like missing (examples: ['nan'])
#  - Risk Factor - Exercise: 97 string-like missing (examples: ['nan'])
#  - Risk Factor - Stress: 112 string-like missing (examples: ['nan'])
#  - Risk Factor - Smoking: 82 string-like missing (examples: ['nan'])
#  - Risk Factor - BMI: 102 string-like missing (examples: ['nan'])
#  - Risk Factor - ECHO - EF: 151 string-like missing (examples: ['nan'])
#  - Test Today - Termination Cause: 20 string-like missing (examples: ['nan'])
#  - Test Today - peak HR: 11 string-like missing (examples: ['nan'])
#  - Test Today - METS: 8 string-like missing (examples: ['nan'])
#  - ECG Resting: 140 string-like missing (examples: ['nan'])
#  - RISK  - Risk Type: 9 string-like missing (examples: ['nan'])
#  - Diagnosis: 87 string-like missing (examples: ['nan'])
#  - Cooling Down: 113 string-like missing (examples: ['nan'])
# ------------------------------------------------------------
# 3) Cleaning object columns: ['Gender', 'Marital Status', 'Lives With', 'Living Environment', 'Occupation', 'Smoking', 'Alcoholic', 'Family History', 'Exercise Habit - Frequency', 'Exercise Habit - Mode', 'Exercise Habit - Duration', 'ROM', 'Balance in Sitting and Standing', 'Functional Activity', 'Walking', 'Gait', 'Posture', 'Risk Factor - HPT', 'Risk Factor - DM', 'Risk Factor - HPL', 'Risk Factor - Family hx', 'Risk Factor - Exercise', 'Risk Factor - Stress', 'Risk Factor - Smoking', 'Risk Factor - BMI', 'Risk Factor - ECHO - EF', 'Test Today - Termination Cause', 'Test Today - peak HR', 'Test Today - METS', 'ECG Resting', 'RISK  - Risk Type', 'Diagnosis', 'Cooling Down']
# ------------------------------------------------------------
# 4) After cleaning: dtype and NaN counts:
# Alcoholic                          226
# Living Environment                 181
# Risk Factor - HPL                  174
# Exercise Habit - Duration          152
# Risk Factor - ECHO - EF            151
# ECG Resting                        140
# Risk Factor - HPT                  133
# Family History                     126
# Occupation                         119
# Exercise Habit - Frequency         117
# Smoking                            115
# Cooling Down                       113
# Risk Factor - Stress               112
# Risk Factor - BMI                  102
# Exercise Habit - Mode              102
# Lives With                         100
# Marital Status                      98
# Risk Factor - Family hx             97
# Risk Factor - Exercise              97
# Diagnosis                           87
# Risk Factor - Smoking               82
# Risk Factor - DM                    82
# Posture                             26
# Test Today - Termination Cause      20
# Target HR (bpm)                     19
# Functional Activity                 17
# Walking                             17
# Gait                                14
# Balance in Sitting and Standing     14
# ROM                                 12
# Test Today - peak HR                11
# Muscle Power - LL - Left            10
# Muscle Power - LL - Right           10
# Muscle Power - UL - Right            9
# RISK  - Risk Type                    9
# Muscle Power - UL - Left             9
# Test Today - METS                    8
# dtype: int64
# Total missing: 2911
# ------------------------------------------------------------
# Dropped columns (missing > 60%): ['Alcoholic']
# Remaining columns: (330, 40)
# Remaining columns: ['Year', 'Gender', 'Age', 'Marital Status', 'Lives With', 'Living Environment', 'Occupation', 'Smoking', 'Family History', 'Exercise Habit - Frequency', 'Exercise Habit - Mode', 'Exercise Habit - Duration', 'ROM', 'Muscle Power - UL - Right', 'Muscle Power - UL - Left', 'Muscle Power - LL - Right', 'Muscle Power - LL - Left', 'Balance in Sitting and Standing', 'Functional Activity', 'Walking', 'Gait', 'Posture', 'Risk Factor - HPT', 'Risk Factor - DM', 'Risk Factor - HPL', 'Risk Factor - Family hx', 'Risk Factor - Exercise', 'Risk Factor - Stress', 'Risk Factor - Smoking', 'Risk Factor - BMI', 'Risk Factor - ECHO - EF', 'Test Today - Termination Cause', 'Test Today - peak HR', 'Test Today - METS', 'ECG Resting', 'RISK  - Risk Type', 'Diagnosis', 'Target HR (bpm)', 'Cooling Down', 'Predicted Risk Level Encoded']

# %%
# Prior New Feature Creation
# Convert raw text columns to numerical data
# CLEANING NUMERIC-TEXT MIXED COLUMNS

import re

def extract_mean_number(val):
    if isinstance(val, (int, float)):
        return float(val)

    if pd.isna(val):
        return np.nan

    text = str(val).strip().lower()

    if text in ['unknown', 'none', '-', '--', '', 'to confirm']:
        return np.nan

    nums = re.findall(r'\d+', text)
    if not nums:
        return np.nan

    return float(np.mean([float(n) for n in nums]))


# ONLY apply to TRUE mixed columns
freq_col = 'Exercise Habit - Frequency'
dur_col  = 'Exercise Habit - Duration'
bmi_col  = 'Risk Factor - BMI'
ef_col   = 'Risk Factor - ECHO - EF'

# Frequency & Duration → numeric
df[freq_col] = df[freq_col].apply(extract_mean_number)
df[dur_col]  = df[dur_col].apply(extract_mean_number)

# BMI → ordinal mapping
bmi_map = {'underweight': 1, 'healthy': 2, 'overweight': 3, 'obese': 4}
df[bmi_col] = df[bmi_col].astype(str).str.strip().str.lower().replace(bmi_map)
df[bmi_col] = pd.to_numeric(df[bmi_col], errors='coerce')

# EF → ordinal mapping
ef_map = {'reduced': 1, 'borderline': 2, 'normal': 3}
df[ef_col] = df[ef_col].astype(str).str.strip().str.lower().replace(ef_map)
df[ef_col] = pd.to_numeric(df[ef_col], errors='coerce')

# %%
# Create derived features (weekly duration, muscle power)
# Weekly Exercise Duration
if 'Weekly_Exercise_Duration' not in df.columns:
    df['Weekly_Exercise_Duration'] = df['Exercise Habit - Frequency'] * df['Exercise Habit - Duration']

# Muscle power columns
muscle_cols = ['Muscle Power - UL - Right', 'Muscle Power - UL - Left',
               'Muscle Power - LL - Right', 'Muscle Power - LL - Left']

# Ensure all muscle columns exist, fill missing with 0
for c in muscle_cols:
    if c not in df.columns:
        df[c] = 0

# Derived features
df['Total_Muscle_Power'] = df[muscle_cols].sum(axis=1)
df['Average_Lower-Limb_Muscle_Power'] = (df['Muscle Power - LL - Right'] + df['Muscle Power - LL - Left']) / 2
df['Average_Upper-Limb_Muscle_Power'] = (df['Muscle Power - UL - Right'] + df['Muscle Power - UL - Left']) / 2

print("Remaining columns:", df.shape)
print("Remaining columns:", df.columns.tolist())
# Out:
# Remaining columns: (330, 44)
# Remaining columns: ['Year', 'Gender', 'Age', 'Marital Status', 'Lives With', 'Living Environment', 'Occupation', 'Smoking', 'Family History', 'Exercise Habit - Frequency', 'Exercise Habit - Mode', 'Exercise Habit - Duration', 'ROM', 'Muscle Power - UL - Right', 'Muscle Power - UL - Left', 'Muscle Power - LL - Right', 'Muscle Power - LL - Left', 'Balance in Sitting and Standing', 'Functional Activity', 'Walking', 'Gait', 'Posture', 'Risk Factor - HPT', 'Risk Factor - DM', 'Risk Factor - HPL', 'Risk Factor - Family hx', 'Risk Factor - Exercise', 'Risk Factor - Stress', 'Risk Factor - Smoking', 'Risk Factor - BMI', 'Risk Factor - ECHO - EF', 'Test Today - Termination Cause', 'Test Today - peak HR', 'Test Today - METS', 'ECG Resting', 'RISK  - Risk Type', 'Diagnosis', 'Target HR (bpm)', 'Cooling Down', 'Predicted Risk Level Encoded', 'Weekly_Exercise_Duration', 'Total_Muscle_Power', 'Average_Lower-Limb_Muscle_Power', 'Average_Upper-Limb_Muscle_Power']

# %%
# TARGET CLEANING

# Keep original numeric target (optional but good practice)
y_original = df[target_col].copy()

# Define bins and labels (Intensity-style)
bins = [0.0, 80, 110, 140, 170]
labels = ['50-80', '80-110', '110-140', '140-170']

# Convert numeric → categorical bins
df[target_col] = pd.cut(
    df[target_col].astype(float),
    bins=bins,
    labels=labels,
    right=False
)

# Check distribution
print("\nTarget distribution:")
print(df[target_col].value_counts().sort_index())

print("Final labels:", df[target_col].unique())

# REMOVE NaN TARGET ROWS
df = df.dropna(subset=[target_col]).copy()

# DEFINE X AND y
X = df.drop(columns=[target_col])
y = df[target_col].astype(str)

# ENCODE TARGET
from sklearn.preprocessing import LabelEncoder

le_y = LabelEncoder()
y_enc = le_y.fit_transform(y)

print("\nEncoded classes:")
print(dict(zip(le_y.classes_, le_y.transform(le_y.classes_))))
print("Shape:", df.shape)
# Out:
# Target distribution:
# Target HR (bpm)
# 50-80       14
# 80-110     187
# 110-140    105
# 140-170      5
# Name: count, dtype: int64
# Final labels: ['80-110', '110-140', NaN, '50-80', '140-170']
# Categories (4, object): ['50-80' < '80-110' < '110-140' < '140-170']
#
# Encoded classes:
# {'110-140': np.int64(0), '140-170': np.int64(1), '50-80': np.int64(2), '80-110': np.int64(3)}
# Shape: (311, 44)

# %%
# Train-test split
from sklearn.model_selection import train_test_split

X = df.drop(columns=[target_col])
y = df[target_col]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

print("Train:", X_train.shape, "Test:", X_test.shape)
# Out:
# Train: (248, 43) Test: (63, 43)

# %%
# Imputation
from sklearn.impute import KNNImputer
import pandas as pd
import numpy as np

X_train_imp = X_train.copy()
X_test_imp = X_test.copy()

# Identify column types
import numpy as np
import pandas as pd

# NUMERICAL
num_cols = X_train.select_dtypes(include=['int64','float64']).columns.tolist()

# CATEGORICAL
cat_cols = X_train.select_dtypes(include=['object','category']).columns.tolist()

print("Numerical:", num_cols)
print("Categorical:", cat_cols)
# Separate column types
num_cols = X_train_imp.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_cols = X_train_imp.select_dtypes(include=['object']).columns.tolist()

print("Numerical cols:", len(num_cols))
print("Categorical cols:", len(cat_cols))

# Encode categorical → numeric (TEMP for KNN)
cat_maps = {}

for col in cat_cols:
    X_train_imp[col] = X_train_imp[col].astype('category')
    cat_maps[col] = X_train_imp[col].cat.categories

    # Train encoding
    X_train_imp[col] = X_train_imp[col].cat.codes.replace({-1: np.nan})

    # Test encoding (align categories)
    X_test_imp[col] = pd.Categorical(
        X_test_imp[col],
        categories=cat_maps[col]
    ).codes
    X_test_imp[col] = X_test_imp[col].replace({-1: np.nan})

# KNN Imputer
imputer = KNNImputer(n_neighbors=5, weights='distance')

X_train_imp = pd.DataFrame(
    imputer.fit_transform(X_train_imp),
    columns=X_train.columns
)

X_test_imp = pd.DataFrame(
    imputer.transform(X_test_imp),
    columns=X_test.columns
)

# Convert categorical back
for col in cat_cols:
    categories = cat_maps[col]

    X_train_imp[col] = pd.Categorical.from_codes(
        X_train_imp[col].round().astype(int).clip(0, len(categories)-1),
        categories
    )

    X_test_imp[col] = pd.Categorical.from_codes(
        X_test_imp[col].round().astype(int).clip(0, len(categories)-1),
        categories
    )

print("\nMissing after imputation:")
print("Train:", X_train_imp.isna().sum().sum())
print("Test :", X_test_imp.isna().sum().sum())
# Out:
# Numerical: ['Year', 'Age', 'Exercise Habit - Frequency', 'Exercise Habit - Duration', 'Muscle Power - UL - Right', 'Muscle Power - UL - Left', 'Muscle Power - LL - Right', 'Muscle Power - LL - Left', 'Risk Factor - BMI', 'Risk Factor - ECHO - EF', 'Predicted Risk Level Encoded', 'Weekly_Exercise_Duration', 'Total_Muscle_Power', 'Average_Lower-Limb_Muscle_Power', 'Average_Upper-Limb_Muscle_Power']
# Categorical: ['Gender', 'Marital Status', 'Lives With', 'Living Environment', 'Occupation', 'Smoking', 'Family History', 'Exercise Habit - Mode', 'ROM', 'Balance in Sitting and Standing', 'Functional Activity', 'Walking', 'Gait', 'Posture', 'Risk Factor - HPT', 'Risk Factor - DM', 'Risk Factor - HPL', 'Risk Factor - Family hx', 'Risk Factor - Exercise', 'Risk Factor - Stress', 'Risk Factor - Smoking', 'Test Today - Termination Cause', 'Test Today - peak HR', 'Test Today - METS', 'ECG Resting', 'RISK  - Risk Type', 'Diagnosis', 'Cooling Down']
# Numerical cols: 15
# Categorical cols: 28
#
# Missing after imputation:
# Train: 0
# Test : 0

# %%
# Encoding

from sklearn.preprocessing import LabelEncoder
X_train_final = X_train_imp.copy()
X_test_final = X_test_imp.copy()

categorical_cols = X_train_final.select_dtypes(include=['object', 'category']).columns.tolist()

feature_encoders = {}

for col in categorical_cols:
    le = LabelEncoder()

    # Fit on TRAIN only
    X_train_final[col] = le.fit_transform(X_train_final[col].astype(str))

    # Apply to TEST safely
    mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    X_test_final[col] = (
        X_test_final[col]
        .astype(str)
        .map(mapping)
        .fillna(-1)   # unseen category
        .astype(int)
    )

    feature_encoders[col] = le

print("Encoding complete.")
print("Final shape:", X_train_final.shape)

print("encoded classes:", dict(zip(le_y.classes_, le_y.transform(le_y.classes_))))
print("shape:", df.shape)

# visualize distribution
from collections import Counter
import matplotlib.pyplot as plt

print("encoded distribution:", Counter(y_enc))

plt.figure(figsize=(8, 5))
df[target_col].value_counts().plot(kind='bar')
plt.title(f"sample count per class: {target_col}")
plt.ylabel("count")
plt.xlabel("class")
plt.show()
# Out:
# Encoding complete.
# Final shape: (248, 43)
# encoded classes: {'110-140': np.int64(0), '140-170': np.int64(1), '50-80': np.int64(2), '80-110': np.int64(3)}
# shape: (311, 44)
# encoded distribution: Counter({np.int64(3): 187, np.int64(0): 105, np.int64(2): 14, np.int64(1): 5})

# %%
# CORRELATION

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# USE ORIGINAL CLEANED DATA (before split, before encoding)
X_corr = df.drop(columns=[
    'Risk Level',
    'Predicted Risk Level',
    'Exercise Habit - Frequency'
], errors='ignore')

# keep numeric only
X_corr = X_corr.select_dtypes(include=[np.number])

# handle missing safely
X_corr = X_corr.fillna(X_corr.median())

corr_matrix = X_corr.corr()

threshold = 0.78
to_drop = set()
high_corr_pairs = []

for i in range(len(corr_matrix.columns)):
    for j in range(i):
        val = corr_matrix.iloc[i, j]
        if abs(val) > threshold:
            col1 = corr_matrix.columns[i]
            col2 = corr_matrix.columns[j]

            high_corr_pairs.append((col1, col2, val))

            # consistent rule: drop later column
            to_drop.add(col1)

print("\nHighly Correlated Feature Pairs:")
for c1, c2, v in high_corr_pairs:
    print(f"{c1} <--> {c2} | corr = {v:.2f}")

print("\nFeatures to drop:", to_drop)

X_train = X_train.drop(columns=list(to_drop), errors='ignore')
X_test  = X_test.drop(columns=list(to_drop), errors='ignore')

# Heatmap
if high_corr_pairs:
    # extract unique feature names
    high_corr_features = list(set(
        [c for pair in high_corr_pairs for c in pair[:2]]
    ))

    corr_matrix_filtered = corr_matrix.loc[
        high_corr_features, high_corr_features
    ]

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix_filtered, annot=True, fmt=".2f", cmap="coolwarm")
    plt.title(f"Correlation Heatmap (|corr| > {threshold})")
    plt.show()
# Out:
# Highly Correlated Feature Pairs:
# Muscle Power - LL - Left <--> Muscle Power - LL - Right | corr = 0.80
# Average_Lower-Limb_Muscle_Power <--> Muscle Power - LL - Right | corr = 0.94
# Average_Lower-Limb_Muscle_Power <--> Muscle Power - LL - Left | corr = 0.95
# Average_Upper-Limb_Muscle_Power <--> Muscle Power - UL - Right | corr = 0.94
# Average_Upper-Limb_Muscle_Power <--> Muscle Power - UL - Left | corr = 0.94
#
# Features to drop: {'Muscle Power - LL - Left', 'Average_Upper-Limb_Muscle_Power', 'Average_Lower-Limb_Muscle_Power'}

# %%
# SAVE (data before Feature Selection)
from google.colab import drive
import os, datetime, joblib

drive.mount('/content/drive')

save_dir = f"/content/drive/MyDrive/Int_data_after_corr_{datetime.datetime.now().strftime('%Y%m%d_%H%M')}"
os.makedirs(save_dir, exist_ok=True)

joblib.dump(X_train_final, os.path.join(save_dir, "X_train_final.pkl"))
joblib.dump(X_test_final, os.path.join(save_dir, "X_test_final.pkl"))
joblib.dump(y_train, os.path.join(save_dir, "y_train.pkl"))
joblib.dump(y_test, os.path.join(save_dir, "y_test.pkl"))

print("Saved to:", save_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved to: /content/drive/MyDrive/Int_data_after_corr_20260507_1548

# %%
# Manual drop redundant features
print("Before drop:", X_train_final.shape)

manual_drop = [
    'Muscle Power - LL - Right',
    'Muscle Power - UL - Right',
    'Muscle Power - UL - Left',
    'Muscle Power - LL - Left',
    'Average_Lower-Limb_Muscle_Power',
    'Average_Upper-Limb_Muscle_Power'
]

X_train_fs = X_train_final.drop(columns=manual_drop, errors='ignore')
X_test_fs  = X_test_final.drop(columns=manual_drop, errors='ignore')

print("After drop:", X_train_fs.shape)
# Out:
# Before drop: (248, 43)
# After drop: (248, 37)

# %%
# Prepare Data for Feature Selection
import numpy as np

feature_names = X_train_fs.columns.tolist()

y_train_fs = y_train

# %%
# FEATURE SELECTION

import numpy as np
import pandas as pd

from sklearn.feature_selection import (
    SelectKBest, f_classif, mutual_info_classif, RFE
)
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# SETTINGS
SEED = 42
K = 15

results = {}
importance_tables = {}

feature_names = X_train_fs.columns.tolist()

# SCALE
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_fs)

# -------------------------
# ANOVA (FULL RANKING)
# -------------------------
anova = SelectKBest(score_func=f_classif, k="all")
anova.fit(X_train_scaled, y_train_fs)

anova_scores = pd.Series(anova.scores_, index=feature_names)
results['ANOVA'] = anova_scores.sort_values(ascending=False).head(K).index.tolist()


# -------------------------
# Mutual Information (FULL RANKING)
# -------------------------
mi = SelectKBest(
    score_func=lambda X, y: mutual_info_classif(
        X, y,
        random_state=SEED
    ),
    k="all"
)
mi.fit(X_train_scaled, y_train_fs)

mi_scores = pd.Series(mi.scores_, index=feature_names)
results['Mutual_Info'] = mi_scores.sort_values(ascending=False).head(K).index.tolist()


# -------------------------
# RFE - Logistic Regression (FULL RANKING)
# -------------------------
lr = LogisticRegression(max_iter=5000)

rfe_lr = RFE(estimator=lr, n_features_to_select=1)  # allow full ranking
rfe_lr.fit(X_train_scaled, y_train_fs)

rfe_lr_rank = pd.Series(rfe_lr.ranking_, index=feature_names)
results['RFE_LR'] = rfe_lr_rank.sort_values().head(K).index.tolist()


# -------------------------
# RFE - SVM (FULL RANKING)
# -------------------------
svm = LinearSVC(max_iter=5000)

rfe_svm = RFE(estimator=svm, n_features_to_select=1)
rfe_svm.fit(X_train_scaled, y_train_fs)

rfe_svm_rank = pd.Series(rfe_svm.ranking_, index=feature_names)
results['RFE_SVM'] = rfe_svm_rank.sort_values().head(K).index.tolist()


# -------------------------
# LASSO (FULL RANKING)
# -------------------------
lasso_pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression(
        penalty='l1',
        solver='liblinear',
        max_iter=5000,
        random_state=SEED
    ))
])

lasso_pipe.fit(X_train_fs, y_train_fs)

lasso_model = lasso_pipe.named_steps['model']

lasso_coef = lasso_model.coef_
lasso_scores = np.abs(lasso_coef).sum(axis=0)

lasso_series = pd.Series(lasso_scores, index=feature_names)

results['LASSO'] = lasso_series.sort_values(ascending=False).head(K).index.tolist()


# -------------------------
# Random Forest Feature Importance (FULL RANKING)
# -------------------------
rf = RandomForestClassifier(
    n_estimators=300,
    random_state=SEED,
    n_jobs=-1
)

rf.fit(X_train_fs, y_train_fs)

rf_scores = pd.Series(rf.feature_importances_, index=feature_names)

results['RF'] = rf_scores.sort_values(ascending=False).head(K).index.tolist()


# -------------------------
# OUTPUT
# -------------------------
print("\n=== FEATURE SELECTION RESULTS (TOP 15 FINAL) ===")
for m, f in results.items():
    print(f"\n{m}: {len(f)}")
    print(f)
# Out:
# === FEATURE SELECTION RESULTS (TOP 15 FINAL) ===
#
# ANOVA: 15
# ['Test Today - peak HR', 'Age', 'RISK  - Risk Type', 'Predicted Risk Level Encoded', 'Test Today - Termination Cause', 'Test Today - METS', 'Exercise Habit - Mode', 'Occupation', 'Risk Factor - Stress', 'Exercise Habit - Duration', 'Risk Factor - ECHO - EF', 'Diagnosis', 'ROM', 'ECG Resting', 'Risk Factor - DM']
#
# Mutual_Info: 15
# ['Test Today - peak HR', 'Test Today - METS', 'Functional Activity', 'Age', 'RISK  - Risk Type', 'Living Environment', 'ROM', 'Risk Factor - Smoking', 'Predicted Risk Level Encoded', 'Weekly_Exercise_Duration', 'Walking', 'Gait', 'Risk Factor - Stress', 'Posture', 'Lives With']
#
# RFE_LR: 15
# ['Age', 'Test Today - peak HR', 'Predicted Risk Level Encoded', 'RISK  - Risk Type', 'Risk Factor - Stress', 'Gender', 'Risk Factor - DM', 'Test Today - Termination Cause', 'Risk Factor - Family hx', 'Risk Factor - HPL', 'Cooling Down', 'ECG Resting', 'Test Today - METS', 'Diagnosis', 'Exercise Habit - Duration']
#
# RFE_SVM: 15
# ['Predicted Risk Level Encoded', 'RISK  - Risk Type', 'Test Today - peak HR', 'Age', 'Exercise Habit - Duration', 'Gender', 'Risk Factor - Stress', 'Risk Factor - DM', 'Occupation', 'Risk Factor - Smoking', 'Smoking', 'Risk Factor - ECHO - EF', 'Marital Status', 'Gait', 'Test Today - METS']
#
# LASSO: 15
# ['Age', 'Test Today - peak HR', 'Risk Factor - DM', 'Risk Factor - ECHO - EF', 'Exercise Habit - Duration', 'RISK  - Risk Type', 'Gender', 'Occupation', 'Risk Factor - BMI', 'Gait', 'Test Today - Termination Cause', 'Risk Factor - Stress', 'Diagnosis', 'Exercise Habit - Mode', 'Walking']
#
# RF: 15
# ['Age', 'Test Today - peak HR', 'Exercise Habit - Duration', 'Weekly_Exercise_Duration', 'Test Today - Termination Cause', 'Risk Factor - ECHO - EF', 'Exercise Habit - Frequency', 'Risk Factor - BMI', 'RISK  - Risk Type', 'ECG Resting', 'Predicted Risk Level Encoded', 'Occupation', 'Diagnosis', 'Exercise Habit - Mode', 'Year']

# %%
# CREATE RANK TABLE (ONLY SELECTED FEATURES)
import pandas as pd
import numpy as np
K = 15
rank_dict = results.copy()

# Ensure strict top-15 enforcement (safety check)
for method in rank_dict:
    rank_dict[method] = rank_dict[method][:K]

max_len = K

for key in rank_dict:
    rank_dict[key] += ['—'] * (max_len - len(rank_dict[key]))

rank_table = pd.DataFrame(rank_dict)
rank_table.insert(0, 'Rank', range(1, max_len + 1))

print("\n=== CONSISTENT FEATURE RANK TABLE (TOP 15 ONLY) ===")
print(rank_table)
# Out:
# === CONSISTENT FEATURE RANK TABLE (TOP 15 ONLY) ===
#     Rank                           ANOVA                   Mutual_Info  \
# 0      1            Test Today - peak HR          Test Today - peak HR
# 1      2                             Age             Test Today - METS
# 2      3               RISK  - Risk Type           Functional Activity
# 3      4    Predicted Risk Level Encoded                           Age
# 4      5  Test Today - Termination Cause             RISK  - Risk Type
# 5      6               Test Today - METS            Living Environment
# 6      7           Exercise Habit - Mode                           ROM
# 7      8                      Occupation         Risk Factor - Smoking
# 8      9            Risk Factor - Stress  Predicted Risk Level Encoded
# 9     10       Exercise Habit - Duration      Weekly_Exercise_Duration
# 10    11         Risk Factor - ECHO - EF                       Walking
# 11    12                       Diagnosis                          Gait
# 12    13                             ROM          Risk Factor - Stress
# 13    14                     ECG Resting                       Posture
# 14    15                Risk Factor - DM                    Lives With
#
#                             RFE_LR                       RFE_SVM  \
# 0                              Age  Predicted Risk Level Encoded
# 1             Test Today - peak HR             RISK  - Risk Type
# 2     Predicted Risk Level Encoded          Test Today - peak HR
# 3                RISK  - Risk Type                           Age
# 4             Risk Factor - Stress     Exercise Habit - Duration
# 5                           Gender                        Gender
# 6                 Risk Factor - DM          Risk Factor - Stress
# 7   Test Today - Termination Cause              Risk Factor - DM
# 8          Risk Factor - Family hx                    Occupation
# 9                Risk Factor - HPL         Risk Factor - Smoking
# 10                    Cooling Down                       Smoking
# 11                     ECG Resting       Risk Factor - ECHO - EF
# 12               Test Today - METS                Marital Status
# 13                       Diagnosis                          Gait
# 14       Exercise Habit - Duration             Test Today - METS
#
#                              LASSO                              RF
# 0                              Age                             Age
# 1             Test Today - peak HR            Test Today - peak HR
# 2                 Risk Factor - DM       Exercise Habit - Duration
# 3          Risk Factor - ECHO - EF        Weekly_Exercise_Duration
# 4        Exercise Habit - Duration  Test Today - Termination Cause
# 5                RISK  - Risk Type         Risk Factor - ECHO - EF
# 6                           Gender      Exercise Habit - Frequency
# 7                       Occupation               Risk Factor - BMI
# 8                Risk Factor - BMI               RISK  - Risk Type
# 9                             Gait                     ECG Resting
# 10  Test Today - Termination Cause    Predicted Risk Level Encoded
# 11            Risk Factor - Stress                      Occupation
# 12                       Diagnosis                       Diagnosis
# 13           Exercise Habit - Mode           Exercise Habit - Mode
# 14                         Walking                            Year

# %%
# Save Feature Selection Output
import joblib, os, datetime

save_dir = f"/content/drive/MyDrive/Int_FS_results_{datetime.datetime.now().strftime('%Y%m%d_%H%M')}"
os.makedirs(save_dir, exist_ok=True)

for method, feats in results.items():
    joblib.dump(feats, os.path.join(save_dir, f"{method}.pkl"))

print("All feature sets saved.")
# Out:
# All feature sets saved.

# %%
# Heatmap
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Use results directly (IMPORTANT FIX)
method_features = {
    method: set(features)
    for method, features in results.items()
}

# Combine all features across methods
all_features = sorted(set().union(*method_features.values()))

# Create binary matrix
feature_matrix = pd.DataFrame(
    {
        method: [1 if f in features else 0 for f in all_features]
        for method, features in method_features.items()
    },
    index=all_features
)

# Print summary
print("\n=== Number of Features Selected by Each Method ===")
for method, features in results.items():
    print(f"{method}: {len(features)} features")

# Plot heatmap
plt.figure(figsize=(12, len(all_features) * 0.4))

sns.heatmap(
    feature_matrix,
    annot=True,
    cmap='YlGnBu',
    cbar=False,
    linewidths=0.5,
    linecolor='gray'
)

plt.title('Feature Selection Comparison Across Methods')
plt.xlabel('Feature Selection Method')
plt.ylabel('Feature Name')

plt.tight_layout()
plt.show()
# Out:
# === Number of Features Selected by Each Method ===
# ANOVA: 15 features
# Mutual_Info: 15 features
# RFE_LR: 15 features
# RFE_SVM: 15 features
# LASSO: 15 features
# RF: 15 features

# %%
# FEATURE CONSENSUS ANALYSIS
from collections import Counter

# Flatten all selected features
all_selected = []
for feats in results.values():
    all_selected.extend(feats)

# Count how many methods selected each feature
feature_counts = Counter(all_selected)

# Convert to DataFrame
consensus_df = pd.DataFrame.from_dict(
    feature_counts, orient='index', columns=['Count']
).sort_values(by='Count', ascending=False)

print("\n=== FEATURE SELECTION FREQUENCY ===")
print(consensus_df)

# =========================================
# GROUP FEATURES BY NUMBER OF METHODS
# =========================================

grouped_features = {}

for k in range(len(results), 0, -1):  # 7 → 1
    grouped_features[k] = consensus_df[consensus_df['Count'] == k].index.tolist()

# Print nicely
print("\n=== FEATURE CONSENSUS GROUPS ===")
for k, feats in grouped_features.items():
    print(f"\nSelected by {k} methods ({len(feats)} features):")
    print(feats)
# Out:
# === FEATURE SELECTION FREQUENCY ===
#                                 Count
# Test Today - peak HR                6
# Age                                 6
# RISK  - Risk Type                   6
# Predicted Risk Level Encoded        5
# Exercise Habit - Duration           5
# Risk Factor - Stress                5
# Test Today - Termination Cause      4
# Test Today - METS                   4
# Risk Factor - DM                    4
# Occupation                          4
# Risk Factor - ECHO - EF             4
# Diagnosis                           4
# Exercise Habit - Mode               3
# ECG Resting                         3
# Gait                                3
# Gender                              3
# Walking                             2
# ROM                                 2
# Risk Factor - Smoking               2
# Weekly_Exercise_Duration            2
# Risk Factor - BMI                   2
# Functional Activity                 1
# Posture                             1
# Living Environment                  1
# Lives With                          1
# Risk Factor - Family hx             1
# Cooling Down                        1
# Risk Factor - HPL                   1
# Smoking                             1
# Marital Status                      1
# Exercise Habit - Frequency          1
# Year                                1
#
# === FEATURE CONSENSUS GROUPS ===
#
# Selected by 6 methods (3 features):
# ['Test Today - peak HR', 'Age', 'RISK  - Risk Type']
#
# Selected by 5 methods (3 features):
# ['Predicted Risk Level Encoded', 'Exercise Habit - Duration', 'Risk Factor - Stress']
#
# Selected by 4 methods (6 features):
# ['Test Today - Termination Cause', 'Test Today - METS', 'Risk Factor - DM', 'Occupation', 'Risk Factor - ECHO - EF', 'Diagnosis']
#
# Selected by 3 methods (4 features):
# ['Exercise Habit - Mode', 'ECG Resting', 'Gait', 'Gender']
#
# Selected by 2 methods (5 features):
# ['Walking', 'ROM', 'Risk Factor - Smoking', 'Weekly_Exercise_Duration', 'Risk Factor - BMI']
#
# Selected by 1 methods (11 features):
# ['Functional Activity', 'Posture', 'Living Environment', 'Lives With', 'Risk Factor - Family hx', 'Cooling Down', 'Risk Factor - HPL', 'Smoking', 'Marital Status', 'Exercise Habit - Frequency', 'Year']
